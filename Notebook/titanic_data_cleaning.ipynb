# %% [markdown]
# # Data Cleaning with Pandas: Titanic Dataset
#
# In this notebook we clean the Titanic dataset step by step, following our class slides.
#
# **Workflow:**
# 1. Load and inspect the data
# 2. Warm up: `loc` and `iloc`
# 3. Handle missing values
# 4. Remove duplicates
# 5. Fix data types
# 6. Handle outliers
# 7. Clean text and categories
# 8. Verify and save
#
# **Golden rule:** Inspect before cleaning, verify after cleaning.

# %% [markdown]
# ## Step 0: Load the Data
#
# If you have `titanic.csv` in the same folder, use that. Otherwise the second line loads it from the internet.

# %%
import pandas as pd

# Option 1: local file
# df = pd.read_csv('../data/titanic_dataset.csv')

# Option 2: load from the internet

df = pd.read_csv("../data/titanic_dataset.csv")

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Step 1: Inspect the Data
#
# Never clean blindly. First understand what you have.

# %%
df.shape   # (rows, columns)
# Out:
# (1309, 12)

# %%
df.info()   # types + non-null counts (most useful first check)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     1309 non-null   int64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 122.8+ KB

# %%
df.describe()   # statistics of numeric columns
# Out:
#        PassengerId     Survived       Pclass          Age        SibSp  \
# count  1309.000000  1309.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000     0.377387     2.294882    29.881138     0.498854
# std     378.020061     0.484918     0.837836    14.413493     1.041658
# min       1.000000     0.000000     1.000000     0.170000     0.000000
# 25%     328.000000     0.000000     2.000000    21.000000     0.000000
# 50%     655.000000     0.000000     3.000000    28.000000     0.000000
# 75%     982.000000     1.000000     3.000000    39.000000     1.000000
# max    1309.000000     1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %% [markdown]
# **What we can already see from `info()`:**
# - `Age` has missing values (count is less than total rows)
# - `Cabin` is mostly missing
# - `Embarked` is missing in 2 rows

# %% [markdown]
# ## Step 2: Warm Up with `loc` and `iloc`
#
# `loc` selects by **name (label)**. `iloc` selects by **position number**.
#
# Pattern: `df.loc[rows, columns]`

# %%
# one cell: row 0, column 'Age'
df.loc[0, 'Age']
# Out:
# np.float64(22.0)

# %%
# some rows, some columns (loc includes the end label 4)
df.loc[0:4, ['Name', 'Age', 'Fare']]
# Out:
#                                                 Name   Age     Fare
# 0                            Braund, Mr. Owen Harris  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  71.2833
# 2                             Heikkinen, Miss. Laina  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  53.1000
# 4                           Allen, Mr. William Henry  35.0   8.0500

# %%
# iloc: same idea but with position numbers (stops BEFORE 5)
df.iloc[0:5, [3, 5, 9]]
# Out:
#                                                 Name   Age     Fare
# 0                            Braund, Mr. Owen Harris  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  71.2833
# 2                             Heikkinen, Miss. Laina  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  53.1000
# 4                           Allen, Mr. William Henry  35.0   8.0500

# %% [markdown]
# ### `loc` with conditions (filtering)
#
# This is the most important skill in this notebook.

# %%
# passengers older than 60
df.loc[df['Age'] > 60, ['Name', 'Age', 'Survived']]
# Out:
#                                                    Name   Age  Survived
# 33                                Wheadon, Mr. Edward H  66.0         0
# 54                       Ostby, Mr. Engelhart Cornelius  65.0         0
# 96                            Goldschmidt, Mr. George B  71.0         0
# 116                                Connors, Mr. Patrick  70.5         0
# 170                           Van der hoef, Mr. Wyckoff  61.0         0
# 252                           Stead, Mr. William Thomas  62.0         0
# 275                   Andrews, Miss. Kornelia Theodosia  63.0         1
# 280                                    Duane, Mr. Frank  65.0         0
# 326                           Nysveen, Mr. Johan Hansen  61.0         0
# 438                                   Fortune, Mr. Mark  64.0         0
# 456                           Millet, Mr. Francis Davis  65.0         0
# 483                              Turkula, Mrs. (Hedwig)  63.0         1
# 493                             Artagaveytia, Mr. Ramon  71.0         0
# 545                        Nicholson, Mr. Arthur Ernest  64.0         0
# 555                                  Wright, Mr. George  62.0         0
# 570                                  Harris, Mr. George  62.0         1
# 625                               Sutton, Mr. Frederick  61.0         0
# 630                Barkworth, Mr. Algernon Henry Wilson  80.0         1
# 672                         Mitchell, Mr. Henry Michael  70.0         0
# 745                        Crosby, Capt. Edward Gifford  70.0         0
# 829           Stone, Mrs. George Nelson (Martha Evelyn)  62.0         1
# 851                                 Svensson, Mr. Johan  74.0         0
# 893                           Myles, Mr. Thomas Francis  62.0         0
# 904                                Howard, Mr. Benjamin  63.0         0
# 972                                  Straus, Mr. Isidor  67.0         0
# 987   Cavendish, Mrs. Tyrell William (Julia Florence...  76.0         1
# 1005             Straus, Mrs. Isidor (Rosalie Ida Blun)  63.0         1
# 1033                         Ryerson, Mr. Arthur Larned  61.0         0
# 1043                                 Storey, Mr. Thomas  60.5         0
# 1070  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  64.0         1
# 1084                                  Lingane, Mr. John  61.0         0
# 1127                           Warren, Mr. Frank Manley  64.0         0
# 1196  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  64.0         1

# %%
# females in first class (use & for AND, | for OR, brackets around each condition)
df.loc[(df['Sex'] == 'female') & (df['Pclass'] == 1)].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 11           12         1       1
# 31           32         1       1
# 52           53         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
#
#     Parch    Ticket      Fare Cabin Embarked
# 1       0  PC 17599   71.2833   C85        C
# 3       0    113803   53.1000  C123        S
# 11      0    113783   26.5500  C103        S
# 31      0  PC 17569  146.5208   B78        C
# 52      0  PC 17572   76.7292   D33        C

# %% [markdown]
# ### `loc` for updating values
#
# `loc` is the **safe** way to change values. Select with a condition, then write into those rows.

# %%
# label children and adults
df.loc[df['Age'] < 16, 'Group'] = 'Child'
df.loc[df['Age'] >= 16, 'Group'] = 'Adult'

df[['Name', 'Age', 'Group']].head(10)
# Out:
#                                                 Name   Age  Group
# 0                            Braund, Mr. Owen Harris  22.0  Adult
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  Adult
# 2                             Heikkinen, Miss. Laina  26.0  Adult
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  Adult
# 4                           Allen, Mr. William Henry  35.0  Adult
# 5                                   Moran, Mr. James   NaN    NaN
# 6                            McCarthy, Mr. Timothy J  54.0  Adult
# 7                     Palsson, Master. Gosta Leonard   2.0  Child
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  Adult
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0  Child

# %% [markdown]
# Note: rows where `Age` is missing got neither label, so their `Group` is `NaN`. We will fix `Age` next, then you can rerun the labeling.
#
# We used `Group` only for practice. Let us drop it before cleaning.

# %%
df = df.drop(columns=['Group'])

# %% [markdown]
# ## Step 3: Missing Values
#
# ### 3.1 Find them first

# %%
df.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
# as percentage (easier to decide what to do)
(df.isnull().mean() * 100).round(1)
# Out:
# PassengerId     0.0
# Survived        0.0
# Pclass          0.0
# Name            0.0
# Sex             0.0
# Age            20.1
# SibSp           0.0
# Parch           0.0
# Ticket          0.0
# Fare            0.1
# Cabin          77.5
# Embarked        0.2
# dtype: float64

# %%
# look at some rows where Age is missing, using loc
df.loc[df['Age'].isnull(), ['Name', 'Age', 'Pclass']]
# Out:
#                                  Name  Age  Pclass
# 5                    Moran, Mr. James  NaN       3
# 17       Williams, Mr. Charles Eugene  NaN       2
# 19            Masselmani, Mrs. Fatima  NaN       3
# 26            Emir, Mr. Farred Chehab  NaN       3
# 28      O'Dwyer, Miss. Ellen "Nellie"  NaN       3
# ...                               ...  ...     ...
# 1299  Riordan, Miss. Johanna Hannah""  NaN       3
# 1301           Naughton, Miss. Hannah  NaN       3
# 1304               Spector, Mr. Woolf  NaN       3
# 1307              Ware, Mr. Frederick  NaN       3
# 1308         Peter, Master. Michael J  NaN       3
#
# [263 rows x 3 columns]

# %% [markdown]
# ### 3.2 Decide and act
#
# | Column | Missing | Decision |
# |--------|---------|----------|
# | Cabin | ~77% | **Drop the column** (too empty to be useful) |
# | Embarked | 2 rows | **Fill with mode** (most common port) |
# | Age | ~20% | **Fill with median** (too important to drop) |

# %%
# drop Cabin
df = df.drop(columns=['Cabin'])

# %%
# fill Embarked with the mode (most common value)
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.loc[df['Embarked'].isna(), 'Embarked'] = df['Embarked'].mode()[0]

# %%
# Calculate the median
median_age = df['Age'].median()
print('Median age:', median_age)

# Fill only missing Age values with the median
df.loc[df['Age'].isna(), 'Age'] = median_age
# Out:
# Median age: 28.0

# %%
# verify: no missing values should remain
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# dtype: int64

# %% [markdown]
# **Why median and not mean?** The mean gets pulled by outliers (a few very old passengers), the median does not.
#
# ## Step 4: Duplicates
#
# The real Titanic data has no duplicates, so let us **create some on purpose** to practice.

# %%
# check first
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# add the first 3 rows again as fake duplicates
df = pd.concat([df, df.iloc[0:3]], ignore_index=True)

print('Rows now:', len(df))
print('Duplicates now:', df.duplicated().sum())
# Out:
# Rows now: 1312
# Duplicates now: 3

# %%
# look at the duplicated rows using loc
df.loc[df.duplicated(), ['Name', 'Age', 'Fare']]
# Out:
#                                                    Name   Age     Fare
# 1309                            Braund, Mr. Owen Harris  22.0   7.2500
# 1310  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  71.2833
# 1311                             Heikkinen, Miss. Laina  26.0   7.9250

# %%
# remove them
df = df.drop_duplicates()

print('Rows after:', len(df))
print('Duplicates after:', df.duplicated().sum())
# Out:
# Rows after: 1309
# Duplicates after: 0

# %% [markdown]
# ## Step 5: Fix Data Types

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
# Survived and Pclass are categories in disguise; Sex and Embarked are true categories
df['Survived'] = df['Survived'].astype(int)
df['Sex'] = df['Sex'].astype('category')
df['Embarked'] = df['Embarked'].astype('category')

df.dtypes
# Out:
# PassengerId       int64
# Survived          int64
# Pclass            int64
# Name             object
# Sex            category
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket           object
# Fare            float64
# Embarked       category
# dtype: object

# %%
df.loc[:, 'Survived'] = df['Survived'].astype(int)
df.loc[:, 'Sex'] = df['Sex'].astype('category')
df.loc[:, 'Embarked'] = df['Embarked'].astype('category')

df.dtypes
# Out:
# PassengerId       int64
# Survived          int64
# Pclass            int64
# Name             object
# Sex            category
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket           object
# Fare            float64
# Embarked       category
# dtype: object

# %%
df['Fare'].describe()
# Out:
# count    1308.000000
# mean       33.295479
# std        51.758668
# min         0.000000
# 25%         7.895800
# 50%        14.454200
# 75%        31.275000
# max       512.329200
# Name: Fare, dtype: float64

# %%
# see the extreme fares with loc
df.loc[df['Fare'] > 300, ['Name', 'Pclass', 'Fare']]
# Out:
#                                                    Name  Pclass      Fare
# 258                                    Ward, Miss. Anna       1  512.3292
# 679                  Cardeza, Mr. Thomas Drake Martinez       1  512.3292
# 737                              Lesurer, Mr. Gustave J       1  512.3292
# 1234  Cardeza, Mrs. James Warburton Martinez (Charlo...       1  512.3292

# %%
# IQR rule
Q1 = df['Fare'].quantile(0.25)
Q3 = df['Fare'].quantile(0.75)
IQR = Q3 - Q1
upper = Q3 + 1.5 * IQR

print('Q1:', Q1, ' Q3:', Q3, ' Upper limit:', round(upper, 2))
print('Outliers:', (df['Fare'] > upper).sum())
# Out:
# Q1: 7.8958  Q3: 31.275  Upper limit: 66.34
# Outliers: 171

# %% [markdown]
# **Decision time.** The 512 fare was a real luxury ticket, not a mistake. Removing real data loses information.
#
# A common middle path is **capping**: pull extreme values down to the upper limit instead of deleting rows.

# %%
# cap Fare at the upper limit using loc
df.loc[df['Fare'] > upper, 'Fare'] = upper

df['Fare'].describe()
# Out:
# count    1308.000000
# mean       24.287208
# std        20.795666
# min         0.000000
# 25%         7.895800
# 50%        14.454200
# 75%        31.275000
# max        66.343800
# Name: Fare, dtype: float64

# %% [markdown]
# ## Step 7: Clean Text and Categories
#
# The real `Sex` column is already clean, so let us **make it messy on purpose**, then clean it.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     1309 non-null   int64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   category
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Embarked     1309 non-null   category
# dtypes: category(2), float64(2), int64(5), object(2)
# memory usage: 105.1+ KB

# %%
print('Missing values:', df.isnull().sum().sum())
print('Duplicates:', df.duplicated().sum())
print('Shape:', df.shape)
# Out:
# Missing values: 1
# Duplicates: 0
# Shape: (1309, 11)

# %%
# Save the cleaned dataset next to the raw one
df.to_csv('../data/titanic_clean.csv', index=False)
print('Saved ../data/titanic_clean.csv')
print('Shape:', df.shape)
# Out:
# Saved ../data/titanic_clean.csv
# Shape: (1309, 11)

# %% [markdown]
# ## Practice Exercises
#
# Use `loc` wherever possible.
#
# 1. Select the `Name`, `Age` and `Fare` of all passengers younger than 10.
# 2. How many third class passengers survived? (Filter with `loc`, then count.)
# 3. Rerun the Child/Adult labeling from Step 2. Why does every row get a label now?
# 4. Set the `Fare` of all passengers with `Fare` equal to 0 to the median fare (use `loc`).
# 5. Count missing values per column in the ORIGINAL dataset again and write one sentence for each column explaining your cleaning decision.
# 6. Challenge: create an `AgeGroup` column with values `Child` (below 13), `Teen` (13 to 19), `Adult` (20 to 59), `Senior` (60 plus), using only `loc`.

# %%
# Select the Name, Age and Fare of all passengers younger than 10.
df.loc[df["Age"] < 10 , ["Name", "Age", "Fare"]]
# Out:
#                                           Name   Age     Fare
# 7               Palsson, Master. Gosta Leonard  2.00  21.0750
# 10             Sandstrom, Miss. Marguerite Rut  4.00  16.7000
# 16                        Rice, Master. Eugene  2.00  29.1250
# 24               Palsson, Miss. Torborg Danira  8.00  21.0750
# 43    Laroche, Miss. Simonne Marie Anne Andree  3.00  41.5792
# ...                                        ...   ...      ...
# 1198                 Aks, Master. Philip Frank  0.83   9.3500
# 1245   Dean, Miss. Elizabeth Gladys Millvina""  0.17  20.5750
# 1270               Asplund, Master. Carl Edgar  5.00  31.3875
# 1280               Palsson, Master. Paul Folke  6.00  21.0750
# 1300                 Peacock, Miss. Treasteall  3.00  13.7750
#
# [82 rows x 3 columns]

# %%
# How many third class passengers survived? (Filter with loc, then count.)
df.loc[(df["Pclass"] == 3) & (df["Survived"] == 1)]
# Out:
#       PassengerId  Survived  Pclass  \
# 2               3         1       3
# 8               9         1       3
# 10             11         1       3
# 19             20         1       3
# 22             23         1       3
# ...           ...       ...     ...
# 1274         1275         1       3
# 1299         1300         1       3
# 1300         1301         1       3
# 1301         1302         1       3
# 1303         1304         1       3
#
#                                                    Name     Sex   Age  SibSp  \
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                      Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 19                              Masselmani, Mrs. Fatima  female  28.0      0
# 22                          McGowan, Miss. Anna "Annie"  female  15.0      0
# ...                                                 ...     ...   ...    ...
# 1274                McNamee, Mrs. Neal (Eileen O'Leary)  female  19.0      1
# 1299                    Riordan, Miss. Johanna Hannah""  female  28.0      0
# 1300                          Peacock, Miss. Treasteall  female   3.0      1
# 1301                             Naughton, Miss. Hannah  female  28.0      0
# 1303                     Henriksson, Miss. Jenny Lovisa  female  28.0      0
#
#       Parch              Ticket     Fare Embarked
# 2         0    STON/O2. 3101282   7.9250        S
# 8         2              347742  11.1333        S
# 10        1             PP 9549  16.7000        S
# 19        0                2649   7.2250        C
# 22        0              330923   8.0292        Q
# ...     ...                 ...      ...      ...
# 1274      0              376566  16.1000        S
# 1299      0              334915   7.7208        Q
# 1300      1  SOTON/O.Q. 3101315  13.7750        S
# 1301      0              365237   7.7500        Q
# 1303      0              347086   7.7750        S
#
# [191 rows x 11 columns]

# %%
# Rerun the Child/Adult labeling from Step 2. Why does every row get a label now?
df.loc[df["Age"] < 18, "AgeLabel"] = "Child"
df.loc[df["Age"] >= 18, "AgeLabel"] = "Adult"

# Because the missing ages were filled in Step 3, so every row now has a real
# Age value and falls under one of the two conditions. Before the fill, the NaN
# rows matched neither condition and were left as NaN.
print("Rows without a label:", df["AgeLabel"].isna().sum())
df["AgeLabel"].value_counts()
# Out:
# Rows without a label: 0
# AgeLabel
# Adult    1155
# Child     154
# Name: count, dtype: int64

# %%
# Set the Fare of all passengers with Fare equal to 0 to the median fare (use loc).
median_fare = df["Fare"].median()
print("Rows with Fare == 0 before:", (df["Fare"] == 0).sum())

df.loc[df["Fare"] == 0, "Fare"] = median_fare

print("Rows with Fare == 0 after :", (df["Fare"] == 0).sum())
print("Median fare used:", round(median_fare, 2))
# Out:
# Rows with Fare == 0 before: 17
# Rows with Fare == 0 after : 0
# Median fare used: 14.45

# %%
# Count missing values per column in the ORIGINAL dataset again and write one sentence for each column explaining your cleaning decision.
df.isna().sum()


# Age: Age has missing values, so I will fill them using an appropriate statistic such as the median.
# Cabin: Cabin has many missing values, so I may drop the column or create a separate Unknown category depending on the analysis.
# Embarked: Embarked has a small number of missing values, so I can fill them with the most common embarkation port.
# Fare: Fare has no missing values, but zero fares may need investigation/replacement depending on the analysis.
# Name: Name has no missing values, so no cleaning is necessary.
# Sex: Sex has no missing values, so no cleaning is necessary.
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# AgeLabel       0
# dtype: int64

# %%
# Challenge: create an AgeGroup column with values Child (below 13), Teen (13 to 19), Adult (20 to 59), Senior (60 plus), using only loc.

df.loc[df["Age"] < 13, "AgeGroup"] = "Child"
df.loc[(df["Age"] >= 13) & (df["Age"] <= 19), "AgeGroup"] = "Teen"
df.loc[(df["Age"] >= 20) & (df["Age"] <= 59), "AgeGroup"] = "Adult"
df.loc[df["Age"] >= 60, "AgeGroup"] = "Senior"

df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ...           ...       ...     ...
# 1304         1305         0       3
# 1305         1306         1       1
# 1306         1307         0       3
# 1307         1308         0       3
# 1308         1309         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1304                                 Spector, Mr. Woolf    male  28.0      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male  28.0      0
# 1308                           Peter, Master. Michael J    male  28.0      1
#
#       Parch              Ticket     Fare Embarked AgeLabel AgeGroup
# 0         0           A/5 21171   7.2500        S    Adult    Adult
# 1         0            PC 17599  66.3438        C    Adult    Adult
# 2         0    STON/O2. 3101282   7.9250        S    Adult    Adult
# 3         0              113803  53.1000        S    Adult    Adult
# 4         0              373450   8.0500        S    Adult    Adult
# ...     ...                 ...      ...      ...      ...      ...
# 1304      0           A.5. 3236   8.0500        S    Adult    Adult
# 1305      0            PC 17758  66.3438        C    Adult    Adult
# 1306      0  SOTON/O.Q. 3101262   7.2500        S    Adult    Adult
# 1307      0              359309   8.0500        S    Adult    Adult
# 1308      1                2668  22.3583        C    Adult    Adult
#
# [1309 rows x 13 columns]
